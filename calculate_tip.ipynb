# %%
def totalbill(amount):
    choice=(input("do you want to give tip? (yes/no) "))
    if choice== "yes":
        tip=0.05*amount
        print(" tip : ", tip)
        print("totalbill:" , tip + amount)

    else:
        print("bill is ", amount )

a=int(input("enter your total bill "))
totalbill(a)
# Out:
# enter your total bill  5000
# do you want to give tip? (yes/no)  yes
#  tip :  250.0
# totalbill: 5250.0
