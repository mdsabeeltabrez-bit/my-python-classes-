# %%
from datetime import date,time,datetime 
today=date.today()
print(today)
# Out:
# 2026-01-21

# %%
time=datetime.now()
print(time)
# Out:
# 2026-01-21 20:12:44.475094

# %%
print("date:" ,today.day)
print("month:" ,today.month)
print("year:" , today.year)
# Out:
# date: 21
# month: 1
# year: 2026
