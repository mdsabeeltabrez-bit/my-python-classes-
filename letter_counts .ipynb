# %%
sentence=(input("enter any sentence"))
letter=(input(" enter the letter you want me to count"))

i=0
count=0

while i< len(sentence):
    if sentence[ i ]==letter:
        count= count+1
    i=i+1
print(count)
# Out:
# enter any sentence hello hello
#  enter the letter you want me to count l
# 4
