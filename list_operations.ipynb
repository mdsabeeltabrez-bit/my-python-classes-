# %%
list1=["peter", "computer",1,2,3,4,5]
print(len(list1))
# Out:
# 7

# %%
print( list1[4])
# Out:
# 3

# %%
print(list1[0:6])
# Out:
# ['peter', 'computer', 1, 2, 3, 4]

# %%
list2=["sabeel","phone",1,2,3,4]
print(len(list2))
# Out:
# 6

# %%
result=list1+list2
print(result)
# Out:
# ['peter', 'computer', 1, 2, 3, 4, 5, 'sabeel', 'phone', 1, 2, 3, 4]

# %%
list3=.[9,0,68,5,88]
print(m
