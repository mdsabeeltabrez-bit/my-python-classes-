# %%
def calculater():
    num1=int(input("enter num1"))
    num2=int(input("enter num2"))
    sum=num1+num2
    diff=num1-num2
    product=num1*num2
    division=num1/num2
    print("sum: ",sum)
    print("diff: ",diff)
    print("product:",product)
    print("division:",division

print("lets add everything")
calculater()
# Out:
# lets add everything
